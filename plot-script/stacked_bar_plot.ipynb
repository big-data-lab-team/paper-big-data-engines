# %%
import os

import plot
from plot import idle_time, wasted_time

col_names = ["func", "start", "end", "filename", "worker", "thread", "process"]
benchmark_dir = f"../results/benchmarks"
fig_dir = "../latex/figures"

# %%
idle_func = idle_time

# %%
def func_remap(df):
    df["func"] =  df["func"].replace(
        {
            "dump": "write",
            "load": "read",
        }
    )
    return df

# %% [markdown]
# # Increment

# %%
experiment = "increment"
parameters = ["n_worker", "block_size", "iterations", "delay"]

# %%
kwargs = {
    "iterations": 5,
    "delay": 1.0,
    "block_size": 5000,
}
xlabel = "# of Nodes"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Increment: Nodes",
    ylim=180_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_increment_worker.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*increment:n_worker=*:block_size=5000:iterations=5:delay=1.0'
# dask:
# [[ 3405.76352587  7988.28664346 19243.84171431]
#  [ 8396.34954321 20870.60757353 47347.92340264]
#  [25501.65282023 25508.98548303 25505.92202981]
#  [ 1754.33473485  3529.47734494  8284.216905  ]]
# spark:
# [[ 3414.92777553  8472.0077724  20418.42020411]
#  [ 8285.38104362 22460.40818005 52332.84554465]
#  [25448.7615705  25443.82438667 25445.17962506]
#  [  688.7393049   1192.95201175  2179.84673064]]

# %%
kwargs = {
    "delay": 1.0,
    "n_worker": 4,
    "block_size": 5000,
}
xlabel = "# of Iterations"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Increment: Iteration",
    ylim=180_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_increment_itr.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*increment:n_worker=4:block_size=5000:iterations=*:delay=1.0'
# dask:
# [[ 11569.11680744   7988.28664346   1625.15776117]
#  [ 30953.65730453  20870.60757353   7801.50849142]
#  [  5101.8251565   25508.98548303 127331.16390436]
#  [  2306.98078413   3529.47734494  12487.57594719]]
# spark:
# [[ 11882.77593305   8472.0077724    2274.24258873]
#  [ 33522.69925587  22460.40818005   6382.46314418]
#  [  5069.24095755  25443.82438667 127343.45168059]
#  [  1147.09669867   1192.95201175   1447.32987728]]

# %%
kwargs = {
    "iterations": 5,
    "n_worker": 4,
    "delay": 1.0,
}
xlabel = "# of Files"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Increment: Files",
    ylim=180_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_increment_block.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*increment:n_worker=4:block_size=*:iterations=5:delay=1.0'
# dask:
# [[11762.2291431   8012.74547827  7988.28664346]
#  [25085.7482841  24375.75637393 20870.60757353]
#  [ 5582.10439048 13010.19578438 25508.98548303]
#  [ 4962.90859771  3444.34529972  3529.47734494]]
# spark:
# [[12469.78901813  8295.72268655  8472.0077724 ]
#  [27576.44726157 26826.93206377 22460.40818005]
#  [ 5394.12339594 12908.58251226 25443.82438667]
#  [ 1071.95249252  1116.28179049  1192.95201175]]

# %% [markdown]
# # Kmeans

# %%
experiment = "kmeans"
parameters = ["n_worker", "block_size", "iterations"]

# %%
kwargs = {
    "iterations": 3,
    "block_size": 5000,
}
xlabel = "# of Nodes"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Kmeans: Nodes",
    ylim=1_200_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_kmeans_worker.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*kmeans:n_worker=*:block_size=5000:iterations=3'
# dask:
# [[  353.5249995    510.66339242  1560.31536746]
#  [ 3246.39967203  3107.52993987  2576.19818769]
#  [19426.3477962  27885.45949934 55270.40640728]
#  [36132.16792805 34985.37083905 31001.86345153]
#  [30851.35792196 29740.21411796 24566.17155848]
#  [26270.37229357 31197.29789703 45092.8146313 ]]
# spark:
# [[6.08409789e+02 8.76078284e+02 4.58855678e+03]
#  [5.30356895e+03 4.70773025e+03 4.90237386e+03]
#  [2.06556042e+04 2.85921496e+04 6.28784243e+04]
#  [1.44778934e+05 1.07238064e+05 6.67272888e+04]
#  [3.26312820e+04 2.99554799e+04 1.59227573e+04]
#  [7.91170667e+05 8.01888996e+05 6.89715593e+05]]

# %%
kwargs = {
    "n_worker": 4,
    "block_size": 5000,
}
xlabel = "# of Iterations"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Kmeans: Iteration",
    ylim=1_200_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_kmeans_itr.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*kmeans:n_worker=4:block_size=5000:iterations=*'
# dask:
# [[  522.21595669   510.66339242]
#  [  923.84596751  3107.52993987]
#  [25117.80131824 27885.45949934]
#  [10550.58583813 34985.37083905]
#  [29734.59058096 29740.21411796]
#  [18270.76981802 31197.29789703]]
# spark:
# [[   976.80294399    876.07828388]
#  [  1910.11177642   4707.73024564]
#  [ 28379.36252279  28592.14955196]
#  [ 22547.6816658  107238.06441953]
#  [ 27369.62816575  29955.47985146]
#  [289130.25261269 801888.99632099]]

# %% [markdown]
# # Histogram

# %%
experiment = "histogram"
parameters = ["n_worker", "block_size"]

# %%
kwargs = {
    "block_size": 5000,
}

xlabel = "# of Nodes"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Histogram: Nodes",
    ylim=70_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_histogram_worker.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*histogram:n_worker=*:block_size=5000'
# dask:
# [[1.67063189e-01 1.89194870e-01 1.54788971e-01]
#  [5.69266635e+03 1.38002515e+04 3.44732348e+04]
#  [4.96966431e+03 4.22281527e+03 3.17346940e+03]
#  [2.50647545e+00 1.96295307e+00 1.78629220e+00]
#  [2.08586701e+04 1.80355123e+04 1.49324980e+04]
#  [1.24008447e+03 1.87932559e+03 3.98409812e+03]]
# spark:
# [[9.05072689e-02 5.49028397e-02 7.80566216e-02]
#  [5.89058399e+03 1.51517051e+04 3.77938626e+04]
#  [5.64831791e+03 4.45558995e+03 2.87685512e+03]
#  [2.16837339e+00 1.73294566e+00 1.47162957e+00]
#  [1.81198776e+04 1.50122898e+04 1.21935760e+04]
#  [1.02855215e+03 1.36318293e+03 2.26846692e+03]]

# %%
kwargs = {
    "n_worker": 4,
}

xlabel = "# of Files"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    **kwargs,
    title="Histogram: Files",
    ylim=70_000,
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_histogram_block.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*histogram:n_worker=4:block_size=*'
# dask:
# [[1.02222919e-01 1.76850224e-01 1.89194870e-01]
#  [1.13701138e+04 1.57982696e+04 1.38002515e+04]
#  [4.58062029e+03 4.23801667e+03 4.22281527e+03]
#  [3.32077670e-01 8.86051393e-01 1.96295307e+00]
#  [1.82034521e+04 1.70953043e+04 1.80355123e+04]
#  [2.35877610e+03 1.91696339e+03 1.87932559e+03]]
# spark:
# [[9.75600004e-02 7.90198088e-02 5.49028397e-02]
#  [1.28371092e+04 1.81267339e+04 1.51517051e+04]
#  [4.82027654e+03 4.33134010e+03 4.45558995e+03]
#  [4.43463898e-01 8.81767535e-01 1.73294566e+00]
#  [1.55479067e+04 1.42289956e+04 1.50122898e+04]
#  [1.23015843e+03 1.26964646e+03 1.36318293e+03]]

# %% [markdown]
# # BIDS app

# %%
experiment = "bids"
parameters = ["n_worker"]

# %%
xlabel = "# of Nodes"

plot.stacked_bar(
    benchmark_dir=benchmark_dir,
    experiment=experiment,
    col_names=col_names,
    parameters=parameters,
    xlabel=xlabel,
    idle_func=idle_func,
    title="BIDS Example: Nodes",
    func_remap=func_remap,
    save_name=os.path.join(fig_dir, "stacked_bids.jpg"),
)
# Out:
# benchmark_dir='../results/benchmarks/*bids:n_worker=*'
# dask:
# [[3714.12980313 3656.98733225 3593.08949361]
#  [  35.72887437   29.90622568   28.61469812]
#  [ 545.92951512 1057.70903466 2362.55590589]]
# spark:
# [[3643.18217909 3500.10270963 3353.25854945]
#  [  34.00262616   27.64662337   25.10128551]
#  [ 686.311408   1187.78428214 2144.47514555]]
